# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# Reshape the data
x_train = x_train.reshape((-1, 28, 28, 1))
x_test = x_test.reshape((-1, 28, 28, 1))

# Build the deep learning model with Batch Normalization
model = models.Sequential()

# Convolutional Layer 1
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))

# Convolutional Layer 2
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))

# Convolutional Layer 3
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.BatchNormalization())

# Flatten the output and add Dense layers
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.BatchNormalization())

# Output layer
model.add(layers.Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Display the model summary
model.summary()

# Train the model
model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  batch_normalization (Batch  (None, 26, 26, 32)        128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  batch_normalization_1 (Bat  (None, 11, 11, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 64)          36928
#
#  batch_normalization_2 (Bat  (None, 3, 3, 64)          256
#  chNormalization)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 64)                36928
#
#  batch_normalization_3 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 94218 (368.04 KB)
# Trainable params: 93770 (366.29 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 84s 41ms/step - loss: 0.1002 - accuracy: 0.9707 - val_loss: 0.0431 - val_accuracy: 0.9865
# Epoch 2/10
# 1875/1875 [==============================] - 77s 41ms/step - loss: 0.0415 - accuracy: 0.9870 - val_loss: 0.0452 - val_accuracy: 0.9859
# Epoch 3/10
# 1875/1875 [==============================] - 77s 41ms/step - loss: 0.0312 - accuracy: 0.9901 - val_loss: 0.0337 - val_accuracy: 0.9896
# Epoch 4/10
# 1875/1875 [==============================] - 76s 41ms/step - loss: 0.0251 - accuracy: 0.9921 - val_loss: 0.0512 - val_accuracy: 0.9845
# Epoch 5/10
# 1875/1875 [==============================] - 91s 49ms/step - loss: 0.0205 - accuracy: 0.9935 - val_loss: 0.0240 - val_accuracy: 0.9928
# Epoch 6/10
# 1875/1875 [==============================] - 90s 48ms/step - loss: 0.0172 - accuracy: 0.9948 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 7/10
# 1875/1875 [==============================] - 91s 48ms/step - loss: 0.0144 - accuracy: 0.9951 - val_loss: 0.0291 - val_accuracy: 0.9920
# Epoch 8/10
# 1875/1875 [==============================] - 91s 48ms/step - loss: 0.0124 - accuracy: 0.9960 - val_loss: 0.0306 - val_accuracy: 0.9911
# Epoch 9/10
# 1875/1875 [==============================] - 91s 48ms/step - loss: 0.0100 - accuracy: 0.9971 - val_loss: 0.0322 - val_accuracy: 0.9913
# Epoch 10/10
# 1875/1875 [==============================] - 91s 49ms/step - loss: 0.0101 - accuracy: 0.9966 - val_loss: 0.0280 - val_accuracy: 0.9908

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  batch_normalization (Batch  (None, 26, 26, 32)        128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  batch_normalization_1 (Bat  (None, 11, 11, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 64)          36928
#
#  batch_normalization_2 (Bat  (None, 3, 3, 64)          256
#  chNormalization)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 64)                36928
#
#  batch_normalization_3 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 94218 (368.04 KB)
# Trainable params: 93770 (366.29 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________
