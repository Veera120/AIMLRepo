# %% [markdown]
# # 1.Write a python function that copies a file reading and writing up to 50 characters at a time.

# %%
def copy_file(input_file_path, output_file_path, limit=50):
        with open('stt.txt', 'r') as source_file, open('ST.txt', 'w') as dest_file:
            while True:
                data = source_file.read(limit)
                if not data:
                    break
                dest_file.write(data)
            print("copied a file")
copy_file(input_file_path, output_file_path, limit=50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       7                 dest_file.write(data)
#       8             print("copied a file")
# ----> 9 copy_file(input_file_path, output_file_path, limit=50)
#
# NameError: name 'input_file_path' is not defined

# %% [markdown]
# # 2. Print all numbers present in the text file and print the number of blank spaces in that file

# %%
def extract_numbers_and_count_spaces(file_path):
    with open('2nd.txt', 'r') as file:
        content = file.read()
        import re
        numbers = re.findall(r'\d+', content)
        num_spaces = content.count(' ')
        print("Numbers in the file:", numbers)
        print("Number of blank spaces:", num_spaces)
file_path = '2nd.txt'  
extract_numbers_and_count_spaces(file_path)
# Out:
# Numbers in the file: ['1', '2', '3', '5', '4', '5', '7', '8']
# Number of blank spaces: 19

# %% [markdown]
# # 3. Write a function called sed that takes as arguments a pattern string, a replacement string, and two filenames; it should read the first file and write the contents into the second file (creating it if necessary). If the pattern string appears anywhere in the file, it should be replaced with the replacement string. If an error occurs while opening, reading, writing, or closing files, your program should catch the exception, print an error message, and exit.

# %%
def sed(pattern, replacement, source_file, destination_file):
    try:
        with open('stt.txt', 'r') as source_file:
            content = source_file.read()
            modified_content = content.replace(pattern, replacement)
        with open('third.txt', 'w') as destination_file:
            destination_file.write(modified_content)
    except FileNotFoundError:
        print(f"Error: File '{source_file_name}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")
pattern = "govind"
replacement = "sme"
sed(pattern, replacement, 'sst.txt', 'third.txt')

# %% [markdown]
# # 4. Log File Analysis: You have a log file containing records of user activities on a website. Each line in the file represents a log entry with details like timestamp, user ID, and action performed. Your task is to analyze this log file.

# %% [markdown]
# # A.Write Python code to read the log file and extract specific information, such as the number of unique users or the most common action.

# %%
import re
from collections import Counter

def extract_log_information(log_file_path):
    try:
        unique_users = set()
        actions = []

        with open('logfile.txt', 'r') as file:
            for line in file:
                
                match = re.match(r'(\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}) (\w+) (.+)', line)
                if match:
                    timestamp, user, action = match.groups()

                    
                    unique_users.add(user)

                   
                    actions.append(action)

        
        most_common_action, most_common_action_count = Counter(actions).most_common(1)[0]

        print(f"Number of unique users: {len(unique_users)}")
        print(f"Most common action: {most_common_action} (Count: {most_common_action_count})")

    except FileNotFoundError:
        print("File not found.")
    except Exception as e:
        print(f"An error occurred: {str(e)}")


log_file_path = "logfile.txt"  e
extract_log_information(log_file_path)
# Out:
# An error occurred: list index out of range

# %% [markdown]
# # B.How would you handle large log files efficiently without loading the entire file into memory?

# %%
def process_large_log_file(log_file_path):
    try:
        with open('logfile.txt', 'r') as file:
            for line in file:
                
                print(line.strip())  

    except FileNotFoundError:
        print("File not found.")
    except Exception as e:
        print(f"An error occurred: {str(e)}")

log_file_path = "logfile.txt"  
process_large_log_file(log_file_path)
# Out:
# [2023-09-10 09:58:46] Executing bootstrap tasks
# [2023-09-10 09:58:46] OpenJDK Runtime Environment 17.0.7+7
# [2023-09-10 09:58:46] Product org.eclipse.products.epp.package.java.2023-06
# [2023-09-10 09:58:46] Bundle org.eclipse.oomph.setup 1.26.0.v20230416-0656, build=5945, branch=c5558820f367665758d4d719b7553a02ff4954e0
# [2023-09-10 09:58:46] Bundle org.eclipse.oomph.setup.core 1.27.0.v20230402-0730, build=5945, branch=c5558820f367665758d4d719b7553a02ff4954e0
# [2023-09-10 09:58:46] Bundle org.eclipse.oomph.setup.p2 1.19.0.v20230416-1150, build=5945, branch=c5558820f367665758d4d719b7553a02ff4954e0
# [2023-09-10 09:58:46] Performing P2 Director (Eclipse IDE for Java Developers (2023-06))
# [2023-09-10 09:58:46] Offline = false
# [2023-09-10 09:58:46] Mirrors = true
# [2023-09-10 09:58:46] Resolving 26 requirements from 3 repositories to C:\Users\ADMIN\eclipse\java-2023-062\eclipse
# ...

# %% [markdown]
# # 5. Each line in the file represents a log entry with details like timestamp, user ID, and actionperformed. Your task is to analyze this log file. a. Write Python code to read the log file and extract specific information, such as thenumber of unique users or the most common action. b. How would you handle large log files efficiently without loading the entire file into memory?Text File Search and Replace: You have a text file with a large amount of text, and youwant to search for specific words or phrases and replace them with new content.

# %% [markdown]
# # a. Write Python code to search for and replace text within a text file.

# %%
text_file_path = "fifthprog.txt"
search_string = "sme"
replace_string = "trinee"
with open(text_file_path, 'r') as file:
    file_content = file.read()
modified_content = file_content.replace(search_string, replace_string)
with open(text_file_path, 'w') as file:
    file.write(modified_content)
    
print("Search and replace completed.")
# Out:
# Search and replace completed.

# %% [markdown]
# # b. How would you handle cases where you need to perform multiple replacements ina single pass?

# %%
text_file_path = "fifthprog.txt"
replacement_dict = {
    "old_text1": "AIML",
    "old_text2": "LMIA",
}
try:
    with open(text_file_path, 'r') as file:
        file_content = file.read()

    # Perform the multiple search and replace operations
    for search, replace in replacement_dict.items():
        file_content = file_content.replace(search, replace)

    # Write the modified content back to the file
    with open(text_file_path, 'w') as file:
        file.write(file_content)

    print("Multiple search and replace completed.")
except FileNotFoundError:
    print(f"Text file '{text_file_path}' not found.")
except Exception as e:
    print("An error occurred:", str(e))
# Out:
# Multiple search and replace completed.

# %% [markdown]
# # 6.Write a Python script that concatenates the contents of multiple text files into a single output file. Allow the user to specify the input files and the output file.

# %%
def concatenate_files(input_files, output_file):
    try:
        with open(output_file, 'w') as output:
            for input_file in input_files:
                with open(input_file, 'r') as file:
                    output.write(file.read())
        print(f"Concatenated {len(input_files)} files into '{output_file}'")
    except Exception as e:
        print(f"An error occurred: {str(e)}")

if __name__ == "__main__":
    input_files = []
    
    while True:
        file_path = input("Enter the path of an input file (or 'q' to quit): ")
        if file_path.lower() == 'q':
            break
        input_files.append(file_path)
    
    if not input_files:
        print("No input files provided. Exiting.")
    else:
        output_file = input("Enter the path of the output file: ")
        concatenate_files(input_files, output_file)
# Out:
# Enter the path of an input file (or 'q' to quit): ST
# Enter the path of an input file (or 'q' to quit): stt
# Enter the path of an input file (or 'q' to quit): q
# Enter the path of the output file: ans
# An error occurred: [Errno 2] No such file or directory: 'ST'

# %% [markdown]
# # 7.program

# %%
with open('fruit.txt', 'r') as input_file:
    words = [line.strip() for line in input_file.readlines()]
    word_length_dict = {}
    for word in words:
        word_length_dict[word] = len(word)
        with open('output.txt', 'w') as output_file:
            for word, length in word_length_dict.items():
                output_file.write(f"{word}:{length}\n")
    print("Word-length dictionary has been written to 'output.txt'.")
# Out:
# Word-length dictionary has been written to 'output.txt'.

# %% [markdown]
# # 8.Assume that you are developing a student gradebook system for a school. The systemshould allow teachers to input student grades for various subjects, store the data in files,and provide students with the ability to view their grades.Design a Python program that accomplishes the following tasks:
# i. Teachers should be able to input grades for students in different subjects.
# ii. Store the student grade data in separate text files for each subject
# iii. Students should be able to view their grades for each subject.
# iv. Implement error handling for file operations, such as file not found or
# permission issues.

# %%
import os
def input_grades(subject):
    try:
        file_name = f"{subject}.txt"
        with open(file_name, "a") as file:
            student_name = input("Enter student name: ")
            grade = input(f"Enter {subject} grade for {student_name}: ")
            file.write(f"{student_name}: {grade}\n")
        print(f"Grade for {student_name} in {subject} has been recorded.")
    except IOError as e:
        print(f"Error: {e}")
def view_grades(subject):
    try:
        file_name = f"{subject}.txt"
        if not os.path.exists(file_name):
            print(f"No grades recorded for {subject} yet.")
            return

        with open(file_name, "r") as file:
            print(f"Grades for {subject}:")
            for line in file:
                print(line.strip())
    except IOError as e:
        print(f"Error: {e}")
while True:
    print("\nStudent Gradebook System")
    print("1. Input Grades")
    print("2. View Grades")
    print("3. Exit")

    choice = input("Enter your choice (1/2/3): ")

    if choice == "1":
        subject = input("Enter the subject: ")
        input_grades(subject)
    elif choice == "2":
        subject = input("Enter the subject: ")
        view_grades(subject)
    elif choice == "3":
        break
    else:
        print("Invalid choice. Please enter 1, 2, or 3.")

print("Goodbye!")
# Out:
# Student Gradebook System
# 1. Input Grades
# 2. View Grades
# 3. Exit
# Enter your choice (1/2/3): 1
# Enter the subject: maths
# Enter student name: charan
# Enter maths grade for charan: 10
# Grade for charan in maths has been recorded.
#
# Student Gradebook System
# 1. Input Grades
# 2. View Grades
# 3. Exit
# Enter your choice (1/2/3): piya
# Invalid choice. Please enter 1, 2, or 3.
#
# Student Gradebook System
# 1. Input Grades
# 2. View Grades
# 3. Exit
# Enter your choice (1/2/3): 2
# Enter the subject: social
# No grades recorded for social yet.
#
# Student Gradebook System
# 1. Input Grades
# 2. View Grades
# 3. Exit
# Enter your choice (1/2/3): 3
# Goodbye!
